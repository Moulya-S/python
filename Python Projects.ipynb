# %%
import random

def guess_the_number():
    print("Welcome to the Guess the Number Game!")
    print("I have selected a random number between 1 and 20.")

    secret_number = random.randint(1, 20)
    attempts = 0

    while True:
        try:
            guess = int(input("Enter your guess: "))
            attempts += 1

            if guess < secret_number:
                print("Too low! Try again.")
            elif guess > secret_number:
                print("Too high! Try again.")
            else:
                print(f"Congratulations! You guessed the number {secret_number} in {attempts} attempts.")
                break
        except ValueError:
            print("Invalid input. Please enter a valid number.")

guess_the_number()
# Out:
# Welcome to the Guess the Number Game!
# I have selected a random number between 1 and 20.
# Enter your guess: 10
# Too high! Try again.
# Enter your guess: 5
# Too high! Try again.
# Enter your guess: 2
# Too low! Try again.
# Enter your guess: 3
# Too low! Try again.
# Enter your guess: 4
# Congratulations! You guessed the number 4 in 5 attempts.

# %%
tasks = []

def add_task(task):
    tasks.append({"task": task, "complete": False})

def view_tasks():
    if not tasks:
        print("No tasks found.")
    else:
        print("To Do List:")
        for index, task in enumerate(tasks, start=1):
            status = "Complete" if task["complete"] else "Incomplete"
            print(f"{index}. {task['task']} - {status}")

def mark_as_complete(task_index):
    if 1 <= task_index <= len(tasks):
        tasks[task_index - 1]["complete"] = True
        print("Task completed.")
    else:
        print("Invalid task no.")

while True:
    print("Options:")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Mark as Complete")
    print("4. Exit")

    choice = input("Enter your choice (1-4): ")

    if choice == "1":
        task = input("Enter the task: ")
        add_task(task)
    elif choice == "2":
        view_tasks()
    elif choice == "3":
        task_index = int(input("Enter the task no. to mark as complete: "))
        mark_as_complete(task_index)
    elif choice == "4":
        print("Exit")
        break
    else:
        print("Invalid choice, Please enter a number b/w 1 & 4.")
# Out:
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Mark as Complete
# 4. Exit
# Enter your choice (1-4): 1
# Enter the task: 1.breakfast
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Mark as Complete
# 4. Exit
# Enter your choice (1-4): 1
# Enter the task: 2.work
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Mark as Complete
# 4. Exit
# Enter your choice (1-4): 1
# Enter the task: 3.relax
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Mark as Complete
# 4. Exit
# Enter your choice (1-4): 1
# Enter the task: 4.yoga
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Mark as Complete
# 4. Exit
# Enter your choice (1-4): 1
# Enter the task: 5.sleep
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Mark as Complete
# 4. Exit
# Enter your choice (1-4): 2
# To Do List:
# 1. 1.breakfast - Incomplete
# 2. 2.work - Incomplete
# 3. 3.relax - Incomplete
# 4. 4.yoga - Incomplete
# 5. 5.sleep - Incomplete
# Options:
# 1. Add Task
# 2. View Tasks
# 3. Mark as Complete
# 4. Exit
# Enter your choice (1-4): 3
# ...
